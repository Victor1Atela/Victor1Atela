# %% [markdown]
# <a href="https://colab.research.google.com/github/Victor1Atela/Victor1Atela/blob/main/CAT2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
vic= pd.read_csv('/content/social_media.csv')
print("Shape of the social_media:",vic.shape)
vic.head(1000)
# Out:
# Shape of the social_media: (1000, 8)
#      userID  age  Facebook  Instagram  Twitter  TotalEngagement  \
# 0      1101   22      2.75       1.64     0.21             9.20
# 1      1102   46      2.35       2.69     1.90            12.00
# 2      1103   42      3.91       3.66     0.27            11.33
# 3      1104   59      3.98       3.47     1.67            12.00
# 4      1105   23      3.23       0.54     0.72             6.64
# ..      ...  ...       ...        ...      ...              ...
# 995    2096   57      3.72       3.16     0.88            10.99
# 996    2097   25      3.04       2.40     0.85            12.00
# 997    2098   21      3.82       2.63     1.44            12.00
# 998    2099   57      1.78       2.08     0.49             7.52
# 999    2100   54      0.47       1.57     1.70             5.97
#
#      eligileToVote  votedb4
# 0                1        1
# 1                1        1
# 2                1        1
# 3                1        0
# ...

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
vic =pd.read_csv('/content/social_media.csv')
x= vic.drop('Facebook', axis =1)
y= vic['age']
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.4, random_state=65)
vao= DecisionTreeClassifier(criterion= 'entropy',random_state=62)
vao.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', random_state=62)

# %%
y_prediction= vao.predict(X_test)
print(y_prediction)
# Out:
# [30 18 34 35 52 26 31 19 61 21 46 20 19 46 27 35 28 55 58 65 21 57 24 57
#  56 48 38 29 52 37 30 23 29 62 33 54 26 41 46 25 38 47 53 19 55 31 27 44
#  34 30 35 62 48 23 60 35 64 42 22 28 36 62 53 56 23 31 20 28 18 19 39 31
#  56 56 24 30 59 53 52 40 47 41 41 56 52 41 43 19 26 47 59 53 22 65 53 57
#  35 37 44 34 41 24 56 51 65 19 46 38 38 51 52 53 54 23 29 62 32 46 37 40
#  27 57 58 36 28 60 18 64 48 37 42 40 43 35 35 34 25 26 35 34 62 46 53 26
#  63 27 36 44 58 40 54 45 57 32 44 30 49 59 55 63 19 42 35 34 57 54 58 54
#  60 31 35 35 20 20 49 57 26 47 64 40 59 40 48 57 52 29 64 55 20 64 20 18
#  59 38 22 30 21 64 24 64 54 38 64 18 63 47 22 27 40 62 64 43 59 44 41 26
#  50 44 29 35 33 38 20 38 40 55 24 49 32 37 36 41 38 23 48 32 34 29 45 25
#  20 35 23 27 21 59 64 34 49 50 30 56 33 33 47 65 38 65 59 62 34 41 19 41
#  30 59 18 18 31 56 24 65 37 48 54 43 38 58 52 53 38 57 30 64 21 27 47 26
#  20 57 44 24 57 39 33 56 64 40 55 28 41 27 56 49 46 36 64 65 49 56 34 30
# ...

# %%
accuracy = accuracy_score(y_test,y_prediction)
print ('Accuracy:', accuracy)
print(f"Accuracy: {accuracy:.2f}")
report = classification_report(y_test, y_prediction)
print("Classification report:")
print(report)
conf_matrix= confusion_matrix (y_test,y_prediction)
print ("Confusion Matrix")
print(conf_matrix)
# Out:
# Accuracy: 1.0
# Accuracy: 1.00
# Classification report:
#               precision    recall  f1-score   support
#
#           18       1.00      1.00      1.00        10
#           19       1.00      1.00      1.00         8
#           20       1.00      1.00      1.00        10
#           21       1.00      1.00      1.00         8
#           22       1.00      1.00      1.00         7
#           23       1.00      1.00      1.00         6
#           24       1.00      1.00      1.00         9
#           25       1.00      1.00      1.00         4
#           26       1.00      1.00      1.00         9
#           27       1.00      1.00      1.00         8
#           28       1.00      1.00      1.00         6
#           29       1.00      1.00      1.00         8
#           30       1.00      1.00      1.00        12
#           31       1.00      1.00      1.00        10
#           32       1.00      1.00      1.00         8
# ...

# %%
from sklearn import tree
from sklearn.datasets import load_files, load_iris
import matplotlib.pyplot as plt
iris = load_iris()
plt.figure(figsize=(15,10))
vao = tree.DecisionTreeClassifier()
vao.fit(iris.data, iris.target)
tree.plot_tree(vao, filled=True)
plt.show()

# %%
import joblib
vao = DecisionTreeClassifier(random_state= 62)
vao.fit(X_train, y_train)
joblib.dump(vao, 'decision_tree_model.pkl')
# Out:
# ['decision_tree_model.pkl']

# %%
import joblib
import pandas as pd
loaded_model = joblib.load('/content/decision_tree_model.pkl')
new_data = pd.DataFrame({
    'userID': [4882,2447,4627,8484,8747,2632,4927],
    'age':[32,44,28,67,66,24,31],
    'Instagram':[0.99,1.09,1.92,1.29,1.78,1.76,1.92],
    'Twitter':[0.21,1.23,1.09,0.99,1.90,0.92,1.26],
    'TotalEngagement': [11.23,9.01,8.99,10.29,9.09,11.09,12.02],
    'eligileToVote':[1,0,0,0,1,1,0],
    'votedb4': [0,1,1,1,1,0,1]
    })
prdictions= loaded_model.predict(new_data)
eligileToVote_mapping = {0:"0-Not Eligible",1:"1-Eligible"}
for i, prediction in enumerate(y_prediction):
  label = eligileToVote_mapping
  print(f"Data {i+1}: predicted Outcome = {label}")
# Out:
# Data 1: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# Data 2: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# Data 3: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# Data 4: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# Data 5: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# Data 6: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# Data 7: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# Data 8: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# Data 9: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# Data 10: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# Data 11: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# Data 12: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# Data 13: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# Data 14: predicted Outcome = {0: '0-Not Eligible', 1: '1-Eligible'}
# ...
