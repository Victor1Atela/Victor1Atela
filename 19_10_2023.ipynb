# %% [markdown]
# <a href="https://colab.research.google.com/github/Victor1Atela/Victor1Atela/blob/main/19_10_2023.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
vic=pd.read_csv('/content/StudentsPerformance.csv')
print("shape of the dataset:", vic.shape)
vic.head(1010)
# Out:
# shape of the dataset: (1000, 8)
#      gender race/ethnicity parental level of education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
import pandas as pd
vic=pd.read_csv('/content/StudentsPerformance.csv')
data=vic.loc[:,['math score','reading score']]
data.head(1000)
# Out:
#      math score  reading score
# 0            72             72
# 1            69             90
# 2            90             95
# 3            47             57
# 4            76             78
# ..          ...            ...
# 995          88             99
# 996          62             55
# 997          59             71
# 998          68             78
# 999          77             86
#
# [1000 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
vic=pd.read_csv('/content/StudentsPerformance.csv')
x='math score'
y='reading score'
style='0'
plt.xtable('math score')
plt.ytable('reading score')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-2b0d77f1bba4> in <cell line: 3>()
#       1 import pandas as pd
#       2 import matplotlib.pyplot as plt
# ----> 3 vic=pd.read_csv('/content/StudentsPerformance.csv')
#       4 x='math score'
#       5 y='reading score'
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
# ...
