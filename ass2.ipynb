# %% [markdown]
# <a href="https://colab.research.google.com/github/Victor1Atela/Victor1Atela/blob/main/ass2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
vic=pd.read_csv('/content/roads.csv')
print("shape of the dataset", vic.shape)
vic.head()
# Out:
# shape of the dataset (177, 16)
#    index Reference Number Grid reference Unnamed: 3  Number of Vehicles  \
# 0    NaN              NaN        Easting   Northing                 NaN
# 1    1.0          45H1457         425594     437040                 2.0
# 2    2.0          45H1553         431935     430560                 1.0
# 3    3.0          45H1553         431935     430560                 1.0
# 4    4.0          45H1553         431935     430560                 1.0
#
#   Accident Date  Time_24hr 1st Road Class & No Road Surface  \
# 0           NaN        NaN                 NaN          NaN
# 1     5/17/2017     1825.0                   U          Dry
# 2     5/17/2017     1925.0                A639     Wet/Damp
# 3     5/17/2017     1925.0                A639     Wet/Damp
# 4     5/17/2017     1925.0                A639     Wet/Damp
#
#                  Lighting Conditions          Weather Conditions  \
# 0                                NaN                         NaN
# ...

# %%
import pandas as pd
vic=pd.read_csv('/content/roads.csv')
data=vic.loc[:,['Time_24hr','Age of Casualty']]
data.head(100)
# Out:
#     Time_24hr  Age of Casualty
# 0         NaN              NaN
# 1      1825.0             26.0
# 2      1925.0             19.0
# 3      1925.0             20.0
# 4      1925.0             17.0
# ..        ...              ...
# 95     1430.0             35.0
# 96     1430.0             36.0
# 97     1430.0             52.0
# 98     1200.0             29.0
# 99     2115.0             39.0
#
# [100 rows x 2 columns]

# %%
import pandas as pd
import matplotlib.pyplot as plt
vic=pd.read_csv('/content/roads.csv')
vic.plot(x='Time_24hr', y='Age of Casualty', style ='o')
plt.show()

# %%
import pandas as pd
vic=pd.read_csv('/content/roads.csv')
x=pd.DataFrame(data['Time_24hr'])
y=pd.DataFrame(data['Age of Casualty'])

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
vic = pd.read_csv('/content/roads.csv')
x=pd.DataFrame(data['Time_24hr'])
y=pd.DataFrame(data['Age of Casualty'])
x_train, x_test,y_trainy_test =train_test_split(x,y, test_size=0.2, random_state=1)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-41-311cdd91d9fc> in <cell line: 6>()
#       4 x=pd.DataFrame(data['Time_24hr'])
#       5 y=pd.DataFrame(data['Age of Casualty'])
# ----> 6 x_train, x_test,y_trainy_test =train_test_split(x,y, test_size=0.2, random_state=1)
#
# ValueError: too many values to unpack (expected 3)
